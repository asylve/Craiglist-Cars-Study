# %%
import pandas as pd
cars = pd.read_csv('cars_cleaned.csv')
cars.columns
# Out:
# Index(['condition', 'drive', 'fuel', 'location', 'odometer', 'paint color',
#        'price', 'sale type', 'title status', 'transmission', 'type',
#        'cylinders', 'size', 'latitude', 'longitude', 'year', 'age', 'make_',
#        'model', 'pos_words', 'neg_words', 'low_text', 'model0', 'model1',
#        'model2'],
#       dtype='object')

# %%
cars.shape
# Out:
# (37341, 25)

# %%
cars.head()
# Out:
#     condition    drive     fuel   location  odometer paint color  price  \
# 0        good      4wd      gas  vancouver    281000       white   5500
# 1     unknown  unknown      gas  vancouver    140000     unknown    600
# 2   excellent      rwd   diesel  vancouver    110000       white  67000
# 3     unknown  unknown      gas  vancouver    243000     unknown   4000
# 4     salvage  unknown      gas  vancouver    225000       black   1500
#
#   sale type title status transmission  ...  year age  make_   model  \
# 0     owner      rebuilt    automatic  ...  2007  14    bmw      x3
# 1     owner        clean    automatic  ...  1984  37  honda  accord
# 2     owner        clean    automatic  ...  2008  13    gmc   c7500
# 3     owner        clean    automatic  ...  2003  18  acura     rsx
# 4     owner      salvage    automatic  ...  2005  16  acura     rsx
#
#    pos_words  neg_words  low_text  model0 model1  model2
# 0      False      False     False      x3   None    None
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for col in ['condition', 'drive', 'fuel', 'location', 'paint color', 'sale type', 'title status', 'transmission', 'type', 
            'cylinders', 'size', 'year']:
    dat = cars[col].value_counts()
    print(col)
    sns.barplot(x = dat.index, y = dat, figsize=(15,8))
    plt.show()
# Out:
# condition
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-5896fadbcfa9> in <module>
#       6     dat = cars[col].value_counts()
#       7     print(col)
# ----> 8     sns.barplot(x = dat.index, y = dat, figsize=(15,8))
#       9     plt.show()
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3175         ax = plt.gca()
#    3176
# -> 3177     plotter.plot(ax, kwargs)
#    3178     return ax
#    3179
#
# ...

# %%
#the civic is by far the most popular car on craiglist in the area
cars.model0.value_counts()[:50].plot.bar(figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
com_cars = cars.model0.value_counts()[:50].index

com_price = cars[cars.model0.isin(com_cars)].groupby(['model0']).price.mean()
com_price.plot.bar(figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='model0'>

# %%
cars.price.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
cars = cars.drop(cars[cars.price>500000].index, axis=0)
